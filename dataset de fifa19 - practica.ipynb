# %%
import pandas as pd

# %%
data = pd.read_csv("datafifa.csv")

# %%
data
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
data.columns.values
# Out:
# array(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage',
#        'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face',
#        'Position', 'Jersey Number', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW',
#        'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM',
#        'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
#        'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping',
#        'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions',
# ...

# %%
subset = data[["Name","Age","Nationality","Club", "Overall","Position"]]

# %%
subset
# Out:
#                        Name  Age          Nationality                    Club  \
# 0                  L. Messi   31            Argentina            FC Barcelona
# 1         Cristiano Ronaldo   33             Portugal                Juventus
# 2                 Neymar Jr   26               Brazil     Paris Saint-Germain
# 3                    De Gea   27                Spain       Manchester United
# 4              K. De Bruyne   27              Belgium         Manchester City
# 5                 E. Hazard   27              Belgium                 Chelsea
# 6                 L. Modrić   32              Croatia             Real Madrid
# 7                 L. Suárez   31              Uruguay            FC Barcelona
# 8              Sergio Ramos   32                Spain             Real Madrid
# 9                  J. Oblak   25             Slovenia         Atlético Madrid
# 10           R. Lewandowski   29               Poland       FC Bayern München
# ...

# %%
subset2 = subset[data["Club"]=="FC Barcelona"]

# %%
subset2
# Out:
#                   Name  Age  Nationality          Club  Overall Position
# 0             L. Messi   31    Argentina  FC Barcelona       94       RF
# 7            L. Suárez   31      Uruguay  FC Barcelona       91       RS
# 18       M. ter Stegen   26      Germany  FC Barcelona       89       GK
# 20     Sergio Busquets   29        Spain  FC Barcelona       89      CDM
# 32            Coutinho   26       Brazil  FC Barcelona       88       LW
# 42           S. Umtiti   24       France  FC Barcelona       87       CB
# 49          Jordi Alba   29        Spain  FC Barcelona       87       LB
# 53          I. Rakitić   30      Croatia  FC Barcelona       87      RCM
# 54               Piqué   31        Spain  FC Barcelona       87      RCB
# 96            A. Vidal   31        Chile  FC Barcelona       85      CAM
# 155         O. Dembélé   21       France  FC Barcelona       83       RW
# 192      Sergi Roberto   26        Spain  FC Barcelona       83       RB
# ...

# %%
subset.describe()
# Out:
#                 Age       Overall
# count  18207.000000  18207.000000
# mean      25.122206     66.238699
# std        4.669943      6.908930
# min       16.000000     46.000000
# 25%       21.000000     62.000000
# 50%       25.000000     66.000000
# 75%       28.000000     71.000000
# max       45.000000     94.000000

# %%
subset3 = subset[data["Overall"]>90]

# %%
subset3
# Out:
#                 Name  Age Nationality                 Club  Overall Position
# 0           L. Messi   31   Argentina         FC Barcelona       94       RF
# 1  Cristiano Ronaldo   33    Portugal             Juventus       94       ST
# 2          Neymar Jr   26      Brazil  Paris Saint-Germain       92       LW
# 3             De Gea   27       Spain    Manchester United       91       GK
# 4       K. De Bruyne   27     Belgium      Manchester City       91      RCM
# 5          E. Hazard   27     Belgium              Chelsea       91       LF
# 6          L. Modrić   32     Croatia          Real Madrid       91      RCM
# 7          L. Suárez   31     Uruguay         FC Barcelona       91       RS
# 8       Sergio Ramos   32       Spain          Real Madrid       91      RCB
